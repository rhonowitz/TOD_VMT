# %% [markdown]
# This notebook is to filter the emission data from the server to exclude test and ineligible participants and trips data collected outside of the data collection timeframe.

# %%
import pandas as pd
import numpy as np

# %%
# emission data 
emission = pd.read_csv("emission_sections_0927.csv")
# emission participants with onboard and offboard dates
timeframe = pd.read_csv("emission_participants.csv")

# %%
timeframe.head()
# Out:
#                  Participant           Site     Onboard    Offboard TOD  \
# 0      cci.vmt.321@gmail.com  Pollard Plaza  10/17/2017   11/2/2017  No
# 1  cci.vmt.study.1@gmail.com  Pollard Plaza  10/17/2017  10/24/2017  No
# 2  cci.vmt.study.3@gmail.com  Pollard Plaza  10/17/2017  10/24/2017  No
# 3         cci.vmt6@gmail.com  Pollard Plaza  10/17/2017  10/24/2017  No
# 4                     hFgWdY       Baycliff  10/19/2017  10/27/2017  No
#
#                 Typology
# 0  Suburban Neighborhood
# 1  Suburban Neighborhood
# 2  Suburban Neighborhood
# 3  Suburban Neighborhood
# 4  Suburban Neighborhood

# %%
len(timeframe)
# Out:
# 95

# %%
len(set(emission["Token"].unique()))
# Out:
# 116

# %%
# filter out tokens not in final token list

participant = set(list(timeframe["Participant"]))
emission = emission[emission["Token"].isin(participant)]
emission = emission.reset_index().drop(["index"], axis = 1)
emission.head()
# Out:
#    Unnamed: 0   Token  distance  \
# 0           0  R7DmtU  0.150621
# 1           1  R7DmtU  0.113001
# 2           2  R7DmtU  0.101308
# 3           3  R7DmtU  0.079180
# 4           4  R7DmtU  0.550268
#
#                                            distances  duration  \
# 0  [0.0, 17.409257855367265, 17.409246950900286, ...      3.25
# 1                          [0.0, 113.00063104524978]      0.25
# 2  [0.0, 38.68727092872398, 28.83404985070727, 25...      1.67
# 3  [0.0, 11.93676605592867, 11.936760555605591, 1...      3.32
# 4  [0.0, 31.326996878971737, 31.924714528769425, ...      9.07
#
#                        end_fmt_time  end_local_dt_day  end_local_dt_hour  \
# 0  2018-03-26T14:58:37.999792-07:00                26                 14
# 1  2018-03-26T15:06:19.999064-07:00                26                 15
# 2  2018-03-26T15:21:15.998857-07:00                26                 15
# 3  2018-03-26T16:03:31.000373-07:00                26                 16
# 4  2018-03-26T19:04:41.998701-07:00                26                 19
#
#    end_local_dt_minute  end_local_dt_month   ...     end_loc_lon  \
# 0                   58                   3   ...     -118.276295
# 1                    6                   3   ...     -118.277293
# 2                   21                   3   ...     -118.282675
# 3                    3                   3   ...     -118.275377
# 4                    4                   3   ...     -118.275233
#
#   start_local_dt_weekday  start_local_dt_year                start_stop  \
# 0                      0                 2018                       NaN
# 1                      0                 2018  5ac07d875ca5a91fe89ff7b0
# 2                      0                 2018  5ac07d875ca5a91fe89ff7b2
# 3                      0                 2018  5ac07d875ca5a91fe89ff7cf
# 4                      0                 2018                       NaN
#
#      start_ts                   trip_id                                  uuid  \
# 0  1522101323  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 1  1522101965  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 2  1522102776  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 3  1522105212  5ac07d875ca5a91fe89ff7b3  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 4  1522115738  5ac07d885ca5a91fe89ff7ed  7512ffe0-c399-4390-af55-2a692ff0cf6c
#
#       Mode  Day of Week  Weekday
# 0  WALKING       Monday        1
# 1  WALKING       Monday        1
# 2  WALKING       Monday        1
# 3  WALKING       Monday        1
# 4  WALKING       Monday        1
#
# [5 rows x 40 columns]

# %%
len(participant)
# Out:
# 95

# %%
len(set(list((emission["Token"].unique()))))
# Out:
# 95

# %%
#Create a new column in the emission dataset that gives the date of each trip_section
emission["day_of_trip"] = emission['start_local_dt_year'].astype(str)+ "." + emission['start_local_dt_month'].astype(str) + "." + emission['start_local_dt_day'].astype(str)

# %%
emission.head()
# Out:
#    Unnamed: 0   Token  distance  \
# 0           0  R7DmtU  0.150621
# 1           1  R7DmtU  0.113001
# 2           2  R7DmtU  0.101308
# 3           3  R7DmtU  0.079180
# 4           4  R7DmtU  0.550268
#
#                                            distances  duration  \
# 0  [0.0, 17.409257855367265, 17.409246950900286, ...      3.25
# 1                          [0.0, 113.00063104524978]      0.25
# 2  [0.0, 38.68727092872398, 28.83404985070727, 25...      1.67
# 3  [0.0, 11.93676605592867, 11.936760555605591, 1...      3.32
# 4  [0.0, 31.326996878971737, 31.924714528769425, ...      9.07
#
#                        end_fmt_time  end_local_dt_day  end_local_dt_hour  \
# 0  2018-03-26T14:58:37.999792-07:00                26                 14
# 1  2018-03-26T15:06:19.999064-07:00                26                 15
# 2  2018-03-26T15:21:15.998857-07:00                26                 15
# 3  2018-03-26T16:03:31.000373-07:00                26                 16
# 4  2018-03-26T19:04:41.998701-07:00                26                 19
#
#    end_local_dt_minute  end_local_dt_month     ...       \
# 0                   58                   3     ...
# 1                    6                   3     ...
# 2                   21                   3     ...
# 3                    3                   3     ...
# 4                    4                   3     ...
#
#    start_local_dt_weekday start_local_dt_year                start_stop  \
# 0                       0                2018                       NaN
# 1                       0                2018  5ac07d875ca5a91fe89ff7b0
# 2                       0                2018  5ac07d875ca5a91fe89ff7b2
# 3                       0                2018  5ac07d875ca5a91fe89ff7cf
# 4                       0                2018                       NaN
#
#      start_ts                   trip_id                                  uuid  \
# 0  1522101323  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 1  1522101965  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 2  1522102776  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 3  1522105212  5ac07d875ca5a91fe89ff7b3  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 4  1522115738  5ac07d885ca5a91fe89ff7ed  7512ffe0-c399-4390-af55-2a692ff0cf6c
#
#       Mode  Day of Week  Weekday  day_of_trip
# 0  WALKING       Monday        1    2018.3.26
# 1  WALKING       Monday        1    2018.3.26
# 2  WALKING       Monday        1    2018.3.26
# 3  WALKING       Monday        1    2018.3.26
# 4  WALKING       Monday        1    2018.3.26
#
# [5 rows x 41 columns]

# %%
#Convert onboard/offboard dates to datetime object
timeframe["Onboard"] = pd.to_datetime(timeframe["Onboard"])
timeframe["Offboard"] = pd.to_datetime(timeframe["Offboard"])

# %%
#Convert emission trip date to datetime object
emission["day_of_trip"] = pd.to_datetime(emission["day_of_trip"])

# %%
emission.head()
# Out:
#    Unnamed: 0   Token  distance  \
# 0           0  R7DmtU  0.150621
# 1           1  R7DmtU  0.113001
# 2           2  R7DmtU  0.101308
# 3           3  R7DmtU  0.079180
# 4           4  R7DmtU  0.550268
#
#                                            distances  duration  \
# 0  [0.0, 17.409257855367265, 17.409246950900286, ...      3.25
# 1                          [0.0, 113.00063104524978]      0.25
# 2  [0.0, 38.68727092872398, 28.83404985070727, 25...      1.67
# 3  [0.0, 11.93676605592867, 11.936760555605591, 1...      3.32
# 4  [0.0, 31.326996878971737, 31.924714528769425, ...      9.07
#
#                        end_fmt_time  end_local_dt_day  end_local_dt_hour  \
# 0  2018-03-26T14:58:37.999792-07:00                26                 14
# 1  2018-03-26T15:06:19.999064-07:00                26                 15
# 2  2018-03-26T15:21:15.998857-07:00                26                 15
# 3  2018-03-26T16:03:31.000373-07:00                26                 16
# 4  2018-03-26T19:04:41.998701-07:00                26                 19
#
#    end_local_dt_minute  end_local_dt_month     ...       \
# 0                   58                   3     ...
# 1                    6                   3     ...
# 2                   21                   3     ...
# 3                    3                   3     ...
# 4                    4                   3     ...
#
#    start_local_dt_weekday start_local_dt_year                start_stop  \
# 0                       0                2018                       NaN
# 1                       0                2018  5ac07d875ca5a91fe89ff7b0
# 2                       0                2018  5ac07d875ca5a91fe89ff7b2
# 3                       0                2018  5ac07d875ca5a91fe89ff7cf
# 4                       0                2018                       NaN
#
#      start_ts                   trip_id                                  uuid  \
# 0  1522101323  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 1  1522101965  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 2  1522102776  5ac07d855ca5a91fe89ff77f  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 3  1522105212  5ac07d875ca5a91fe89ff7b3  7512ffe0-c399-4390-af55-2a692ff0cf6c
# 4  1522115738  5ac07d885ca5a91fe89ff7ed  7512ffe0-c399-4390-af55-2a692ff0cf6c
#
#       Mode  Day of Week  Weekday  day_of_trip
# 0  WALKING       Monday        1   2018-03-26
# 1  WALKING       Monday        1   2018-03-26
# 2  WALKING       Monday        1   2018-03-26
# 3  WALKING       Monday        1   2018-03-26
# 4  WALKING       Monday        1   2018-03-26
#
# [5 rows x 41 columns]

# %%
timeframe.head()
# Out:
#                  Participant           Site    Onboard   Offboard TOD  \
# 0      cci.vmt.321@gmail.com  Pollard Plaza 2017-10-17 2017-11-02  No
# 1  cci.vmt.study.1@gmail.com  Pollard Plaza 2017-10-17 2017-10-24  No
# 2  cci.vmt.study.3@gmail.com  Pollard Plaza 2017-10-17 2017-10-24  No
# 3         cci.vmt6@gmail.com  Pollard Plaza 2017-10-17 2017-10-24  No
# 4                     hFgWdY       Baycliff 2017-10-19 2017-10-27  No
#
#                 Typology
# 0  Suburban Neighborhood
# 1  Suburban Neighborhood
# 2  Suburban Neighborhood
# 3  Suburban Neighborhood
# 4  Suburban Neighborhood

# %%
#Merge two dataframe together
df = emission.merge(timeframe, how = "left", left_on = "Token", right_on = "Participant")

# %%
df.head()
# Out:
#    Unnamed: 0   Token  distance  \
# 0           0  R7DmtU  0.150621
# 1           1  R7DmtU  0.113001
# 2           2  R7DmtU  0.101308
# 3           3  R7DmtU  0.079180
# 4           4  R7DmtU  0.550268
#
#                                            distances  duration  \
# 0  [0.0, 17.409257855367265, 17.409246950900286, ...      3.25
# 1                          [0.0, 113.00063104524978]      0.25
# 2  [0.0, 38.68727092872398, 28.83404985070727, 25...      1.67
# 3  [0.0, 11.93676605592867, 11.936760555605591, 1...      3.32
# 4  [0.0, 31.326996878971737, 31.924714528769425, ...      9.07
#
#                        end_fmt_time  end_local_dt_day  end_local_dt_hour  \
# 0  2018-03-26T14:58:37.999792-07:00                26                 14
# 1  2018-03-26T15:06:19.999064-07:00                26                 15
# 2  2018-03-26T15:21:15.998857-07:00                26                 15
# 3  2018-03-26T16:03:31.000373-07:00                26                 16
# 4  2018-03-26T19:04:41.998701-07:00                26                 19
#
#    end_local_dt_minute  end_local_dt_month     ...         Mode Day of Week  \
# 0                   58                   3     ...      WALKING      Monday
# 1                    6                   3     ...      WALKING      Monday
# 2                   21                   3     ...      WALKING      Monday
# 3                    3                   3     ...      WALKING      Monday
# 4                    4                   3     ...      WALKING      Monday
#
#    Weekday  day_of_trip  Participant            Site    Onboard   Offboard  \
# 0        1   2018-03-26       R7DmtU  MacArthur Park 2018-03-26 2018-04-04
# 1        1   2018-03-26       R7DmtU  MacArthur Park 2018-03-26 2018-04-04
# 2        1   2018-03-26       R7DmtU  MacArthur Park 2018-03-26 2018-04-04
# 3        1   2018-03-26       R7DmtU  MacArthur Park 2018-03-26 2018-04-04
# 4        1   2018-03-26       R7DmtU  MacArthur Park 2018-03-26 2018-04-04
#
#    TOD    Typology
# 0  Yes  Urban Core
# 1  Yes  Urban Core
# 2  Yes  Urban Core
# 3  Yes  Urban Core
# 4  Yes  Urban Core
#
# [5 rows x 47 columns]

# %%
len(df)
# Out:
# 9663

# %%
#Filter based on time
df = df[(df["day_of_trip"] >= df["Onboard"])]
df = df[(df["day_of_trip"] <= df["Offboard"])]

# %%
len(df)
# Out:
# 8317

# %%
# identify tokens with less than 4 trips (we are defining a trip as a section, or row in dataset)
df["Token"].value_counts().sort_values()[:5]
# Out:
# AHLp9w    1
# 9mXnba    5
# DBWNjq    5
# EzCrnr    5
# UkBZ2d    6
# Name: Token, dtype: int64

# %%
# remove users with less than 4 trips
df = df[df.Token != "AHLp9w"]

# %%
len(df)
# Out:
# 8316

# %%
df["Mode"].value_counts()
# Out:
# IN_VEHICLE    4368
# WALKING       2822
# ON_FOOT        384
# UNKNOWN        317
# AIR_OR_HSR     210
# BICYCLING      179
# RUNNING         36
# Name: Mode, dtype: int64

# %%
# rename air/hsr modes to vehicle
df[df["Mode"]=='AIR_OR_HSR'] = 'IN_VEHICLE'

# %%
df["Mode"].value_counts()
# Out:
# IN_VEHICLE    4578
# WALKING       2822
# ON_FOOT        384
# UNKNOWN        317
# BICYCLING      179
# RUNNING         36
# Name: Mode, dtype: int64

# %%
df = df[df.Mode != "UNKNOWN"]

# %%
df["Mode"].value_counts()
# Out:
# IN_VEHICLE    4578
# WALKING       2822
# ON_FOOT        384
# BICYCLING      179
# RUNNING         36
# Name: Mode, dtype: int64

# %%
len(df)
# Out:
# 7999

# %%
df.to_csv("emission_cleaned_10102018.csv")
